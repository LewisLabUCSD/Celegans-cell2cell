# %%
import cell2cell as c2c

import numpy as np
import pandas as pd

from collections import defaultdict

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data_folder = '../../data/'

# %%
import os

output_folder = '../../results/Benchmarking/Classifier-Thresholds/'
if not os.path.isdir(output_folder):
    os.makedirs(output_folder, exist_ok=True)

# %% [markdown]
# # Load Data

# %%
dist = pd.read_csv(data_folder + '/Digital-3D-Map/Celegans_Physical_Distances_Min.csv', index_col=0)

# %%
tpm_values = [5, 10, 50, 100]

bray_curtis = dict()
counts = dict()
smillie = dict()

# %%
for tpm in tpm_values:
    bray_curtis[tpm] = pd.read_csv(data_folder + '/Benchmarking/CCI-Matrix-Bray_curtis-{}-TPM.csv'.format(tpm), index_col=0)
    counts[tpm] = pd.read_csv(data_folder + '/Benchmarking/CCI-Matrix-Count-{}-TPM.csv'.format(tpm), index_col=0)
    smillie[tpm] = pd.read_csv(data_folder + '/Benchmarking/CCI-Matrix-Smillie-{}-TPM.csv'.format(tpm), index_col=0)

# %% [markdown]
# # Preprocessing

# %%
pairs = c2c.core.interaction_space.generate_pairs(dist.columns, cci_type='undirected')

# %%
len(pairs)
# Out:
# 253

# %%
cell_int = [p[0] + '; ' + p[1] for p in pairs]

# %% [markdown]
# **Distance Matrix**

# %%
distances = pd.melt(dist.reset_index(), id_vars='index')
distances.columns = ['Cell1', 'Cell2', 'Distance']

# %%
# Exclude autocrine interactions
distances = distances.loc[distances['Distance'] > 0]

# %%
def define_range(x):
    if x < 5.6:
        return 'Short-Range Distance'
    elif x < 70.:
        return 'Mid-Range Distance'
    else:
        return 'Long-Range Distance'

# %%
distances['Range'] = distances['Distance'].apply(define_range)

# %%
distances['Interaction'] = distances.apply(lambda row: row['Cell1'] + '; ' + row['Cell2'], axis=1)

# %%
distances = distances.loc[distances['Interaction'].isin(cell_int)].reset_index(drop=True)

# %%
distances.head()
# Out:
#                     Cell1                   Cell2  Distance  \
# 0      Am/PH_sheath_cells  Touch_receptor_neurons  3.165871
# 1      Am/PH_sheath_cells  Oxygen_sensory_neurons  1.809980
# 2  Touch_receptor_neurons  Oxygen_sensory_neurons  4.874073
# 3      Am/PH_sheath_cells       GABAergic_neurons  2.386306
# 4  Touch_receptor_neurons       GABAergic_neurons  5.458439
#
#                   Range                                     Interaction
# 0  Short-Range Distance      Am/PH_sheath_cells; Touch_receptor_neurons
# 1  Short-Range Distance      Am/PH_sheath_cells; Oxygen_sensory_neurons
# 2  Short-Range Distance  Touch_receptor_neurons; Oxygen_sensory_neurons
# 3  Short-Range Distance           Am/PH_sheath_cells; GABAergic_neurons
# 4  Short-Range Distance       Touch_receptor_neurons; GABAergic_neurons

# %%
distances.shape
# Out:
# (229, 5)

# %%
for tpm in tpm_values:
    distances['Bray-Curtis-{}-TPM'.format(tpm)] = [bray_curtis[tpm].at[row['Cell1'], row['Cell2']] for idx, row in distances.iterrows()]
    distances['LR Count-{}-TPM'.format(tpm)] = [counts[tpm].at[row['Cell1'], row['Cell2']] for idx, row in distances.iterrows()]
    distances['Smillie-{}-TPM'.format(tpm)] = [smillie[tpm].at[row['Cell1'], row['Cell2']] for idx, row in distances.iterrows()]

# %%
distances.head()
# Out:
#                     Cell1                   Cell2  Distance  \
# 0      Am/PH_sheath_cells  Touch_receptor_neurons  3.165871
# 1      Am/PH_sheath_cells  Oxygen_sensory_neurons  1.809980
# 2  Touch_receptor_neurons  Oxygen_sensory_neurons  4.874073
# 3      Am/PH_sheath_cells       GABAergic_neurons  2.386306
# 4  Touch_receptor_neurons       GABAergic_neurons  5.458439
#
#                   Range                                     Interaction  \
# 0  Short-Range Distance      Am/PH_sheath_cells; Touch_receptor_neurons
# 1  Short-Range Distance      Am/PH_sheath_cells; Oxygen_sensory_neurons
# 2  Short-Range Distance  Touch_receptor_neurons; Oxygen_sensory_neurons
# 3  Short-Range Distance           Am/PH_sheath_cells; GABAergic_neurons
# 4  Short-Range Distance       Touch_receptor_neurons; GABAergic_neurons
#
#    Bray-Curtis-5-TPM  LR Count-5-TPM  Smillie-5-TPM  Bray-Curtis-10-TPM  \
# 0           0.493256           128.0       0.183659            0.436441
# 1           0.545794           146.0       0.314124            0.502041
# 2           0.543071           145.0       0.189801            0.513725
# 3           0.548673           155.0       0.590490            0.488372
# 4           0.542553           153.0       0.563043            0.511194
#
#    LR Count-10-TPM  Smillie-10-TPM  Bray-Curtis-50-TPM  LR Count-50-TPM  \
# 0            103.0        0.360763            0.303207             52.0
# 1            123.0        0.604412            0.290598             51.0
# 2            131.0        0.445390            0.357143             70.0
# 3            126.0        0.382528            0.273973             50.0
# 4            137.0        0.251308            0.305419             62.0
#
#    Smillie-50-TPM  Bray-Curtis-100-TPM  LR Count-100-TPM  Smillie-100-TPM
# 0        0.290179             0.192000              24.0         0.112974
# 1        0.201868             0.212766              30.0         0.219143
# 2        0.577410             0.258278              39.0         0.801343
# 3        0.159047             0.157143              22.0         0.010840
# 4        0.301334             0.193333              29.0         0.164056

# %% [markdown]
# # Analysis

# %%
overall_scores = ['Bray-Curtis', 'LR Count', 'Smillie']
scores = dict()

for cci_score in overall_scores:
    scores[cci_score] = ['{}-{}-TPM'.format(cci_score, tpm) for tpm in tpm_values]

# %% [markdown]
# **Distributions**

# %%
for cci_score in overall_scores:
    if any(distances.columns.str.contains(cci_score)):
        ncols = len(scores[cci_score])
        fig, axes = plt.subplots(nrows=1, ncols=ncols, 
                                 figsize=(7*len(scores), 4.5), sharey=False)

        flat_axes = axes.flatten()
        for i, cci in enumerate(scores[cci_score]):
            ax = flat_axes[i]

            sp1 = sns.histplot(data=distances, x=cci, kde=True, hue='Range', bins=50, ax=ax, 
                               legend=True if i == ncols-1 else False)
            ax.set_xlabel('CCI score', fontdict={'size' : 16})
            ax.set_ylabel('Count', fontdict={'size' : 16})
            ax.set_title("Distribution of CCI scores\nfor {}".format(cci), fontsize=20)

            #ax.set_xlim(0.2, 0.7)
            ax.set_ylim(0, 20.)

        sns.move_legend(ax, "center left", bbox_to_anchor=(1.01, 0.5), ncol=1, fancybox=True, shadow=True,)
        plt.savefig(output_folder + '{}-Distribution-Range.pdf'.format(cci_score), dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Random Forest

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, roc_curve, auc


from xgboost.sklearn import XGBClassifier

# %%
classifier = XGBClassifier(n_estimators=10, n_jobs=10, random_state=0)

# %%
kfolds = 3

# %% [markdown]
# **Data**

# %%
cells = list(dist.columns)

# %%
data_input = distances.copy()
for loc in data_input['Range'].unique():
    data_input[loc] = [1 if (l == loc) else 0 for l in data_input['Range']]

# %%
lab_mapper = LabelEncoder()
data_input['Range_labels'] = lab_mapper.fit_transform(data_input['Range'])

# %%
# Split with Stratified KFold

strat_train_test = dict()

for cci_score in overall_scores:
    if any(data_input.columns.str.contains(cci_score)):
        for cci in scores[cci_score]:
            X = data_input[[cci]]
            y = data_input['Range_labels']
            skf = StratifiedKFold(n_splits=kfolds, random_state=0, shuffle=True)

            tmp_Xys = []
            for train_idx, test_idx in skf.split(X, y):
                tmp_Xys.append((data_input.iloc[train_idx], data_input.iloc[test_idx]))
            strat_train_test[cci] = tmp_Xys

# %% [markdown]
# **Train Classifier**

# %%
# Stratified KFold

class_results = defaultdict(lambda: defaultdict(dict))

auc_records = []


for cci_score in overall_scores:
    if any(data_input.columns.str.contains(cci_score)):
        for cci in scores[cci_score]:
            for n, v in enumerate(strat_train_test[cci]):
                for class_name in lab_mapper.classes_:
                    class_id = lab_mapper.transform([class_name])[0]

                    X_train, y_train = v[0][[cci]], v[0]['Range_labels']
                    X_test, y_test = v[1][[cci]], v[1][class_name]

                    class_tmp = classifier.fit(X_train, y_train)
                    probas = class_tmp.predict_proba(X_test)

                    fpr, tpr, thresholds = roc_curve(y_test, probas[:, class_id], pos_label=1)
                    roc_auc = auc(fpr, tpr)

                    class_results[class_name][cci][n] = (fpr, tpr, roc_auc)

                    auc_records.append((class_name, cci, n, roc_auc))

# %% [markdown]
# **Result Analysis**

# %%
from scipy import interp

# %%
cmaps = dict()
for cci_score in overall_scores:
    if any(data_input.columns.str.contains(cci_score)):
        colors = ['#484A47', '#990099', '#e41a1c', '#f7cb15' ,'#c47335']
        cmaps[cci_score] = dict(zip(scores[cci_score], colors))


        mean_fpr = np.linspace(0, 1, data_input.shape[0])

        fig, axes = plt.subplots(nrows=1, ncols=data_input['Range'].unique().shape[0], 
                                 figsize=(16, 4.5))

        flat_axes = axes.flatten()

        for i, class_name in enumerate(sorted(lab_mapper.classes_)[::-1]):
            ax = flat_axes[i]
            for cci in scores[cci_score]:

                tmp_dict = class_results[class_name][cci]
                tpr_ = []
                auc_ = []

                # Interpolate TPRs and get AUCs for each KFold
                for i in range(kfolds):
                    tmp_fpr = tmp_dict[i][0]
                    tmp_tpr = tmp_dict[i][1]
                    tmp_auc = tmp_dict[i][2]

                    interpolation = interp(mean_fpr, tmp_fpr, tmp_tpr)
                    interpolation[0] = 0.0
                    tpr_.append(interpolation)
                    auc_.append(tmp_auc)

                # Compute mean and std for TPR and AUC
                mean_tpr = np.mean(tpr_, axis=0)
                std_tpr = np.std(tpr_, axis=0)

                mean_auc = np.mean(auc_)
                std_auc = np.std(auc_)

                # Plot results
                ax.plot([0, 1], [0, 1], color="gray", lw=2, linestyle="--") # Diag line
                ax.plot(mean_fpr, mean_tpr, color=cmaps[cci_score][cci],
                        label=r'{} / AUC: {:.2f} $\pm$ {:.2f}'.format(cci, mean_auc, std_auc)
                       ) # Label: ROC curve $\pm$ 1 std 


                tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
                tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
                ax.fill_between(mean_fpr, tprs_lower, tprs_upper,
                                color=cmaps[cci_score][cci], 
                                alpha=.2,
                                )

                ax.set_xlabel("False Positive Rate", fontdict={'size' : 16})
                ax.set_ylabel("True Positive Rate", fontdict={'size' : 16})
                ax.set_title("{}".format(class_name), fontsize=20)


                ax.spines['right'].set_visible(False)
                ax.spines['left'].set_visible(True)
                ax.spines['bottom'].set_visible(True)
                ax.spines['top'].set_visible(False)
                ax.spines['bottom'].set_bounds(0, 1)
                ax.spines['left'].set_bounds(0, 1)

                ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=1, fancybox=True, shadow=True,)


        plt.savefig(output_folder + '/{}-ROC-Curve-Separate-Distances.pdf'.format(cci_score), dpi=300, 
                    bbox_inches='tight')

# %%
for cci_score in overall_scores:
    if any(data_input.columns.str.contains(cci_score)):

        mean_fpr = np.linspace(0, 1, data_input.shape[0])

        fig, axes = plt.subplots(nrows=1, ncols=1, 
                                 figsize=(5, 4.5))

        ax = axes


        for cci in scores[cci_score]:
            tpr_ = []
            auc_ = []

            # Macro-AUC
            for i, class_name in enumerate(sorted(lab_mapper.classes_)[::-1]):
                tmp_dict = class_results[class_name][cci]


                # Interpolate TPRs and get AUCs for each KFold
                for i in range(kfolds):
                    tmp_fpr = tmp_dict[i][0]
                    tmp_tpr = tmp_dict[i][1]
                    tmp_auc = tmp_dict[i][2]

                    interpolation = interp(mean_fpr, tmp_fpr, tmp_tpr)
                    interpolation[0] = 0.0
                    tpr_.append(interpolation)
                    auc_.append(tmp_auc)

            # Compute mean and std for TPR and AUC
            mean_tpr = np.mean(tpr_, axis=0)
            std_tpr = np.std(tpr_, axis=0)

            mean_auc = np.mean(auc_)
            std_auc = np.std(auc_)

            # Plot results
            ax.plot([0, 1], [0, 1], color="gray", lw=2, linestyle="--") # Diag line
            ax.plot(mean_fpr, mean_tpr, color=cmaps[cci_score][cci],
                    label=r'{} / AUC: {:.2f} $\pm$ {:.2f}'.format(cci, mean_auc, std_auc)
                   ) # Label: ROC curve $\pm$ 1 std 


            tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
            tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
            ax.fill_between(mean_fpr, tprs_lower, tprs_upper,
                            color=cmaps[cci_score][cci], 
                            alpha=.2,
                            )

            ax.set_xlabel("False Positive Rate", fontdict={'size' : 16})
            ax.set_ylabel("True Positive Rate", fontdict={'size' : 16})
            ax.set_title("All Distance Ranges", fontsize=20)


            ax.spines['right'].set_visible(False)
            ax.spines['left'].set_visible(True)
            ax.spines['bottom'].set_visible(True)
            ax.spines['top'].set_visible(False)
            ax.spines['bottom'].set_bounds(0, 1)
            ax.spines['left'].set_bounds(0, 1)

            ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=1, fancybox=True, shadow=True,)

        plt.savefig(output_folder + '/{}-ROC-Curve-All-Distances.pdf'.format(cci_score), dpi=300, 
                    bbox_inches='tight')
